# %%
# !pip install pandas scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.0 MB 2.7 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.0 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.0 MB 3.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/8.0 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.0 MB 3.8 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/8.0 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 4.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.5 MB 6.1 MB/s eta 0:00:06
# ...
